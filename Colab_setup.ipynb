# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your Google Drive. (Runtime --> Change runtime type).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own path.

# %%
cd /content/drive/Your_Dir

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Training
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %% [markdown]
# Run the final module below for our standard test case in the report. Testing on our machines resulted in a 17.72 test CER.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=final_module_config \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun

# %% [markdown]
# Run the final module for a full 150 epochs below. This was not the focus of our testing or optimizations and is just here for reference.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=final_module_config \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=150\
  --multirun

# %% [markdown]
# Run a version without dropout below. Testing on our machines resulted in an 18.00 test CER.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=final_module_nodropout \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun

# %% [markdown]
# Run the preoptimized module below with 384 MLP features and 768 as the LSTM hidden size. Testing on our machines resulted in a 19.95 test CER.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=preoptimized_cnn_lstm \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun

# %% [markdown]
# Run the unselected CNN - Vanilla RNN hybrid model.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=tds_conv_ctc_vanillaRNN \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun

# %% [markdown]
# Run the unselected CNN - GRU hybrid model.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=tds_conv_ctc_gru \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun

# %% [markdown]
# RUn the original baseline

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  model=tds_conv_ctc \
  seed=1501 \
  trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=80\
  --multirun
